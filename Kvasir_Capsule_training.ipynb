# %% [markdown]
# Clone source code từ github

# %%
# !git clone https://windyaz374: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@github.com/windyaz374/AI24_LVM-MED.git

# %% [markdown]
# Di chuyển vào thư mục làm việc

# %%
# %cd /content/AI24_LVM-MED

# %% [markdown]
# Check out sang nhánh đang làm việc

# %%
# !git checkout debug/env-setup

# %% [markdown]
# Cài đặt môi trường để training

# %%
# !pip install -r requirements.txt

# %% [markdown]
# Liên kết với drive cá nhân để copy dataset, pre-trained model vào trong source code. Lưu ý trong drive cá nhân đã tải các file trên
# Dataset: [Kvasir_Capsule](https://drive.google.com/file/d/1wg1jbw1d546Q6i6cAvTtdu_fVKQcpHg6/view?usp=drive_link)
# Pre-trained model:
#   + LVM_Med: [LVM_Med_RestNet](https://drive.google.com/file/d/1IjGFfkz0DWRd03yX9YIDJOtHd5nQri_x/view?usp=drive_link) [LVM_Med_VIT](https://drive.google.com/file/d/19_rL8iYb7YRLF2ZtOfj4HUMtE0beTVY_/view?usp=drive_link)
#   + ImageNet: [ImageNet_RestNet](https://drive.google.com/file/d/1-21znpeY6rnwrECi0Tr8XzA8P4tRjKuX/view?usp=drive_link)  [ImageNet_VIT](https://drive.google.com/file/d/1uZBkXU29JotbC1-JLraSOO9yPQAscDu6/view?usp=drive_link)

# %%
from google.colab import drive
drive.mount('/content/gdrive')

# %% [markdown]
# Copy dataset từ drive cá nhân vào trong dataset_demo/.

# %%
# !cp /content/gdrive/MyDrive/AI_Advanced/Kvasir_capsule.zip dataset_demo/.

# %% [markdown]
# Giải nén thư mục dataset

# %%
# !unzip dataset_demo/Kvasir_capsule.zip -d dataset_demo/.

# %% [markdown]
# Split dataset thành thư mục training và testing theo tỉ lệ 8:2

# %%
# !python prepare_dataset.py -ds Kvasir_capsule

# %% [markdown]
# Copy các pre-train model vào source code để tiến hành training

# %%
# !cp /content/gdrive/MyDrive/AI_Advanced/lvmmed_resnet.torch lvm_med_weights/.

# %% [markdown]
# Thực hiện quá trình training. Lần lượt thay đổi các file .yml và các pre-trained model tương ứng

# %%
# !python train_classification.py -c ./dataloader/yaml_data/kvasir_capsule_endtoend_R50_frozen_1_fcn.yml
